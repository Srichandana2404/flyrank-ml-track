# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Srichandana2404/flyrank-ml-track/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below
#
# One row represents a single content‑day performance record for a client in the warehouse.
# The table used is fact_content_daily_performance.
# The time window chosen for verification is March 2026 (a mid‑panel month).

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*
#
# Feature: impressions, clicks, CTR, average position, query length, device type.
#
# Label: engagement rate or ranking score proxy for content performance.
#
# Context: client ID, content ID, date, country, language.
#
# Excluded: raw query text and final month (June 2026) data — excluded to avoid label leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*
#
# Grain check: each row is unique for (client_id + content_id + date).
#
# Row count: total rows for March 2026 ≈ N (you’ll fill in after running the query).
#
# Date span: earliest date = 2026‑03‑01, latest date = 2026‑03‑31.
#
# Availability: filter with IS TRUE on valid metrics (e.g., clicks > 0) and report how many rows survive.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*
#
# This data cannot show cross‑month user journeys or predict future content launches.
# It is limited to daily aggregates and may miss late updates from Search Console.
# Unbalanced history and window overlap are known constraints.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
